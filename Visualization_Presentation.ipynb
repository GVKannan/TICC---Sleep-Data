# %% [markdown]
# Visualization for Presentation

# %%
import pandas as pd
from pandas import Series
import matplotlib.pyplot as plt
import random
import numpy as np
# %matplotlib inline
import time
import csv

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(1,1,1)

c = [ 'b','g','r','c','m','y']
df = pd.read_csv('Week6_Amplitude3_WithClustAssign_1.csv', sep=',')
x = df.iloc[:,0]
z = df.iloc[:,2]
s1 = np.size(x)

ax.plot(x, c = 'k')
#ax2.plot(y, c = 'k')

z = z.astype(int)
#df.a = df.a.astype(float)

for i in range(1,s1):
    p = ax.axvspan(i-1, i, facecolor=c[z[i]], alpha=0.5)
    
pyplot.show()

#fig.savefig("")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-10275646ea40> in <module>()
#      17     p = ax.axvspan(i-1, i, facecolor=c[z[i]], alpha=0.5)
#      18
# ---> 19 pyplot.show()
#      20
#      21 #fig.savefig("")
#
# NameError: name 'pyplot' is not defined

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(1,1,1)

c = [ 'b','g','r','c','m','y']
df = pd.read_csv('Week6_[n=3]_Amplitude_Wave3_WithClusAssign_Beta=300.csv', sep=',')
x = df.iloc[:,0]
z = df.iloc[:,2]
s1 = np.size(x)

ax.plot(x, c = 'k')
#ax2.plot(y, c = 'k')

z = z.astype(int)
#df.a = df.a.astype(float)

for i in range(1,s1):
    p = ax.axvspan(i-1, i, facecolor=c[z[i]], alpha=0.5)
    
pyplot.show()

#fig.savefig("")

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(1,1,1)

c = [ 'b','g','r','c','m','y']
df = pd.read_csv('Week6_[n=3]_Amplitude_Wave3_WithClusAssign_Beta=300.csv', sep=',')
x = df.iloc[:,0]
z = df.iloc[:,2]
s1 = np.size(x)

ax.plot(x, c = 'k')
#ax2.plot(y, c = 'k')

z = z.astype(int)
#df.a = df.a.astype(float)

for i in range(1,s1):
    p = ax.axvspan(i-1, i, facecolor=c[z[i]], alpha=0.5)
    
pyplot.show()

#fig.savefig("")

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(1,1,1)

c = [ 'b','g','r','c','m','y']
df = pd.read_csv('Week6_[n=3]_Amplitude_Wave3_WithClusAssign.csv', sep=',')
x = df.iloc[:,0]
z = df.iloc[:,2]
s1 = np.size(x)

ax.plot(x, c = 'k')
#ax2.plot(y, c = 'k')

z = z.astype(int)
#df.a = df.a.astype(float)

for i in range(1,s1):
    p = ax.axvspan(i-1, i, facecolor=c[z[i]], alpha=0.5)
    
pyplot.show()

#fig.savefig("")

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot(1,1,1)

c = [ 'b','g','r','c','m','y']
df = pd.read_csv('Week5_Mixed[n=6]_Freq_Wave_Final_Amplitude1_1_WithClustAssign.csv', sep=',')
x = df.iloc[:,0]
z = df.iloc[:,2]
s1 = np.size(x)

ax.plot(x, c = 'k')
#ax2.plot(y, c = 'k')

z = z.astype(int)
#df.a = df.a.astype(float)

for i in range(1,s1):
    p = ax.axvspan(i-1, i, facecolor=c[z[i]], alpha=0.5)
    
pyplot.show()

#fig.savefig("")

# %%
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot(1,1,1)

c = [ 'b','g','r','c','m','y']
df = pd.read_csv('Week5_Mixed[n=4]_Freq_Wave_Final_Frequency1_Repeat_WithClustAssign_1.csv', sep=',')
x = df.iloc[:,0]
z = df.iloc[:,2]
s1 = np.size(x)

ax.plot(x, c = 'k')
#ax2.plot(y, c = 'k')

z = z.astype(int)
#df.a = df.a.astype(float)

for i in range(1,s1):
    p = ax.axvspan(i-1, i, facecolor=c[z[i]], alpha=0.5)
    
pyplot.show()

fig.savefig("Univariate Freq Seriesv1 - Highly sensitive - With Repetition")

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot(1,1,1)

c = [ 'b','g','r','c','m','y']
df = pd.read_csv('01Vis1.csv', sep=',')
x = df.iloc[:,0]
z = df.iloc[:,2]
s1 = np.size(x)

ax.plot(x, c = 'k')
#ax2.plot(y, c = 'k')

z = z.astype(int)
#df.a = df.a.astype(float)

for i in range(1,s1):
    p = ax.axvspan(i-1, i, facecolor=c[z[i]], alpha=0.5)
    
pyplot.show()

fig.savefig("01Vis1 - Vis")

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot(1,1,1)

c = [ 'b','g','r','c','m','y']
df = pd.read_csv('01Freq1 - BIC = 65.86376; Beta = 600.csv', sep=',')
x = df.iloc[:,0]
z = df.iloc[:,2]
s1 = np.size(x)

ax.plot(x, c = 'k')
#ax2.plot(y, c = 'k')

z = z.astype(int)
#df.a = df.a.astype(float)

for i in range(1,s1):
    p = ax.axvspan(i-1, i, facecolor=c[z[i]], alpha=0.5)
    
pyplot.show()

fig.savefig("Freq1 - BIC = 65.86376 - Beta = 600.png")

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(1,1,1)

c = [ 'b','g','r','c','m','y']
df = pd.read_csv('01Vis1 - BIC = 77.165; Beta = 175.csv', sep=',')
x = df.iloc[:,0]
z = df.iloc[:,2]
s1 = np.size(x)

ax.plot(x, c = 'k')
#ax2.plot(y, c = 'k')

z = z.astype(int)
#df.a = df.a.astype(float)

for i in range(1,s1):
    p = ax.axvspan(i-1, i, facecolor=c[z[i]], alpha=0.5)
    
pyplot.show()

fig.savefig("Freq1 - BIC = 65.86376 - Beta = 600.png")

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot(1,1,1)

c = [ 'b','g','r','c','m','y']
df = pd.read_csv('01Freq1 - BIC = 7935.48066; Beta = 0.csv', sep=',')
x = df.iloc[:,0]
z = df.iloc[:,2]
s1 = np.size(x)

ax.plot(x, c = 'k')
#ax2.plot(y, c = 'k')

z = z.astype(int)
#df.a = df.a.astype(float)

for i in range(1,s1):
    p = ax.axvspan(i-1, i, facecolor=c[z[i]], alpha=0.5)
    
pyplot.show()

fig.savefig('Freq1 - BIC = 7935.48066 - Beta = 0.png')

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot(1,1,1)

c = [ 'b','g','r','c','m','y']
df = pd.read_csv('01Freq1 - BIC = 144.163; Beta = 100.csv', sep=',')
x = df.iloc[:,0]
z = df.iloc[:,2]
s1 = np.size(x)

ax.plot(x, c = 'k')
#ax2.plot(y, c = 'k')

z = z.astype(int)
#df.a = df.a.astype(float)

for i in range(1,s1):
    p = ax.axvspan(i-1, i, facecolor=c[z[i]], alpha=0.5)
    
pyplot.show()

#fig.savefig("")

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot(1,1,1)

c = [ 'b','g','r','c','y','m']
df = pd.read_csv('01Freq1 - BIC = 198.31978; Beta = 50.csv', sep=',')
x = df.iloc[:,0]
z = df.iloc[:,2]
s1 = np.size(x)

ax.plot(x, c = 'k')
#ax2.plot(y, c = 'k')

z = z.astype(int)
#df.a = df.a.astype(float)

for i in range(1,s1):
    p = ax.axvspan(i-1, i, facecolor=c[z[i]], alpha=0.5)
    
plt.show()

fig.savefig("01Freq1 - BIC = 198.31978 - Beta = 50.png")

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot(1,1,1)

c = [ 'b','g','r','c','y','m']
df = pd.read_csv('01Freq1 - BIC = 157.714842; Beta = 75.csv', sep=',')
x = df.iloc[:,0]
z = df.iloc[:,2]
s1 = np.size(x)

ax.plot(x, c = 'k')
#ax2.plot(y, c = 'k')

z = z.astype(int)
#df.a = df.a.astype(float)

for i in range(1,s1):
    p = ax.axvspan(i-1, i, facecolor=c[z[i]], alpha=0.5)
    
plt.show()

fig.savefig("01Freq1 - BIC = 157.714842 - Beta = 75.png")

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot(1,1,1)

c = [ 'b','g','r','c','y','m']
df = pd.read_csv('01Freq1 - BIC = 144.21454; Beta = 95.csv', sep=',')
x = df.iloc[:,0]
z = df.iloc[:,2]
s1 = np.size(x)

ax.plot(x, c = 'k')
#ax2.plot(y, c = 'k')

z = z.astype(int)
#df.a = df.a.astype(float)

for i in range(1,s1):
    p = ax.axvspan(i-1, i, facecolor=c[z[i]], alpha=0.5)
    
plt.show()

#fig.savefig("")
